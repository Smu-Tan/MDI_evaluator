# %%
from Eval_v5_shaomu import *

# %%
run_test(0.)
# Out:
# Mean values before filtering:
#
# Mean values of ID outliers (Cross Entropy):
# 400.0
#
# Mean values of Full outliers (Cross Entropy):
# 400.0
#
# Mean values of ID outliers (Kullback Leibler):
# 400.0
#
# Mean values of Full outliers (Kullback Leibler):
# 400.0
#
# Mean values after filtering:
#
# Mean values of ID outliers (Cross Entropy):
# 77.28571428571429
#
# Mean values of Full outliers (Cross Entropy):
# 69.71428571428571
#
# Mean values of ID outliers (Kullback Leibler):
# 74.0
#
# Mean values of Full outliers (Kullback Leibler):
# 81.71428571428571

# %%
run_merge_analysis(0.)

# %% [markdown]
# ### Calculate the outlier score for the other criterion

# %%
id_whole_fil_ce_add,id_whole_fil_ts_add,full_whole_fil_ce_add,full_whole_fil_ts_add = compute_other_criterion_outlier_score('color')

# %% [markdown]
# ## Check running time

# %%
plot_running_time()
